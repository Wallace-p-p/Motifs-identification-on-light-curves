# %%
import os
os.chdir('C:\\Users\\Usuario\\Desktop\\wallace\\UNILA\\starlight-curve-project')
import pandas as p
import numpy as np
import matplotlib.pyplot as plt
csv= p.read_csv('exoTrain.csv')
print(csv.shape)
# Out:
# (5087, 3198)

# %%
x= range(3198)
cv= csv.iloc[2:3]
ca= csv.loc[11, :]
ca= ca[1:]
cvl= np.array(cv)
ca= np.array(ca)
plt.plot(ca)
plt.ylabel('Brilho')
plt.xlabel('Tempo')
plt.title('Curva de Luz')
plt.show()

# %%
from biosppy.signals import tools
ind , prof =tools.signal_self_join(signal=ca, size= 15, index=None, limit=None)
plt.plot(prof)
plt.ylabel('Distância')
plt.xlabel('Coordenada X')
plt.title('Matrix Profile')
plt.show()

# %%
print(csv.iloc[0:50])
# Out:
#     LABEL     FLUX.1     FLUX.2     FLUX.3    FLUX.4    FLUX.5    FLUX.6  \
# 0       2      93.85      83.81      20.10    -26.98    -39.56   -124.71
# 1       2     -38.88     -33.83     -58.54    -40.09    -79.31    -72.81
# 2       2     532.64     535.92     513.73    496.92    456.45    466.00
# 3       2     326.52     347.39     302.35    298.13    317.74    312.70
# 4       2   -1107.21   -1112.59   -1118.95  -1095.10  -1057.55  -1034.48
# 5       2     211.10     163.57     179.16    187.82    188.46    168.13
# 6       2       9.34      49.96      33.30      9.63     37.64     20.85
# 7       2     238.77     262.16     277.80    190.16    180.98    123.27
# 8       2    -103.54    -118.97    -108.93    -72.25    -61.46    -50.16
# 9       2    -265.91    -318.59    -335.66   -450.47   -453.09   -561.47
# 10      2     118.81     110.97      79.53    114.25     48.78      3.12
# 11      2    -239.88    -164.28    -180.91   -225.69    -90.66   -130.66
# ...

# %%
a=6
print([0,1,2,3,4])
for i in range(5):
    print(a)
# Out:
# [0, 1, 2, 3, 4]
# 6
# 6
# 6
# 6
# 6

# %%
import numpy as np
import matplotlib.pyplot as plt

x= input()
y= input()
x= x.split()
y= y.split()
for i in range(len(x)):
    x[i]=float(x[i])
    y[i]=y[i].replace(',','.')
    y[i]= float(y[i][0:8])
# Out:
# 0.1849 111.47
# 0 -5

# %%
plt.plot(x,y)
plt.grid()
plt.ylabel('y')
plt.xlabel('x')
plt.title('Figura 5: função obtida do MMQ')
plt.show()
