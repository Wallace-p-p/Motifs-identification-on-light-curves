# %%
import os
os.chdir('C:\\Users\\Usuario\\Desktop\\wallace\\UNILA\\starlight-curve-project\\séries temporais\\owlpy-master\\owlpy')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
cv = pd.read_csv('exoTrain.csv')
a= 6
l= (a +1)
ncv = cv.iloc[a:l]
ncv
label = ncv.pop(ncv.columns[0])
print(ncv.head())

d = ncv.values.flatten()
e = ncv.values.flatten()

from core3 import *

Pdd=test_stamp(d,e,500)
# Out:
#    FLUX.1  FLUX.2  FLUX.3  FLUX.4  FLUX.5  FLUX.6  FLUX.7  FLUX.8  FLUX.9  \
# 6    9.34   49.96    33.3    9.63   37.64   20.85    4.54   22.42   10.11
#
#    FLUX.10    ...      FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  FLUX.3192  \
# 6     40.1    ...         -58.56       9.93       9.93       23.5       5.28
#
#    FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 6      -0.44       10.9     -11.77      -9.25     -36.69
#
# [1 rows x 3197 columns]
# --- 356.3413074016571 seconds ---
# 1444

# %%
I= np.asarray(Pdd)
desv= I.std()
med= I.mean()
ln = len(I)
ln
# Out:
# 2697

# %%
for c in range(ln -1):
    if (I[c - 1]>I[c]<I[c + 1]):
        if( I[c]< (med - desv)):
            print(c)
# Out:
# 1
# 14
# 17
# 136
# 138
# 171
# 176
# 180
# 186
# 190
# 195
# 197
# 199
# 203
# 211
# 221
# 266
# 272
# 277
# 648
# 738
# 741
# 746
# 752
# 754
# 765
# 916
# 918
# 923
# 927
# 930
# 936
# 938
# 1381
# 1383
# 1416
# 1421
# 1425
# 1431
# 1435
# 1440
# 1442
# 1444
# 1448
# 1456
# 1466
# 1511
# 1517
# 1522
# 1540
# 1542
# 1555
# 1558
# 1965
# 2064
# 2069
# 2072
# 2075
# 2077
# 2080
# 2083
# 2255
# 2257
# 2265
# 2351
# 2354
# 2358
# 2418
# 2420
