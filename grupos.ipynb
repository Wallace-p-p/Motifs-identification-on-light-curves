# %%
import os
os.chdir('C:\\Users\\Usuario\\Desktop\\wallace\\UNILA\\starlight-curve-project\\séries temporais\\owlpy-master\\owlpy')

# %%
import pickle
import matplotlib.pyplot as plt
a = pickle.load( open( "grupos 2.txt", "rb" ) )
b=0
print(a[0][0][1])
'''for i in range(a[0][0][0][0]):
 print(i, 'integrantes: ', a[0][0][1][i])'''

'''for i in range(a[0][0][0][0]):
    if a[0][0][1][i] > 700:
        print(i)
        b= b + 1
        print(b)
        #print(a[1][0][i])
        plt.plot(a[1][0][i])
        plt.show()
        
plt.plot(a[0][0][1])
plt.ylabel('Número de subsequências')
plt.xlabel('Grupos')
plt.title('Quantidade de motifs por grupos')
plt.show()'''
# Out:
# [622, 200, 141, 26, 102, 19, 2, 4, 4, 7, 2, 20, 63, 5, 6, 6, 61, 74, 10, 4, 2, 16, 2, 2, 691, 43, 16, 13, 82, 9, 27, 2, 24, 2, 16, 4, 2, 386, 743, 2, 2, 567, 10, 8, 2, 177, 6, 2, 2, 333, 23, 71, 2, 2, 8, 18, 3, 3, 11, 5, 2, 2, 3, 2, 12, 3, 3, 11, 5, 2, 2, 18, 13, 19, 8, 2, 2, 2, 2, 11, 21, 147, 80, 12, 5, 499, 79, 2, 53, 4, 16, 138, 390, 181, 77, 2, 6, 13, 5, 9, 17, 11, 2, 5, 7, 2, 2, 3, 13, 3, 14, 4, 10, 2, 4, 133, 91, 316, 54, 1298, 84, 2, 79, 213, 3, 108, 3, 4, 5, 21, 3, 6, 3, 3, 6, 2, 2, 2, 2, 11, 29, 86, 722, 41, 56, 4, 21, 69, 34, 65, 9, 16, 9, 3, 491, 270, 41, 10, 3, 4, 8, 4, 13, 255, 2, 29, 13, 5, 3, 19, 2, 6, 3, 8, 6, 13, 3, 2, 50, 145, 34, 9, 14, 2, 3, 3, 4, 4, 2, 5, 6, 2, 3, 3, 4, 6, 22, 112, 28, 478, 37, 164, 5, 2, 23, 2, 3, 2, 48, 3, 13, 2, 4, 2, 293, 27, 22, 4, 9, 31, 12, 2, 4, 7, 2, 3, 4, 2, 11, 2, 2, 31, 3, 2, 2, 36, 5, 5, 2, 5, 5, 4, 2, 4, 3, 4, 2, 2, 281, 133, 6, 25, 34, 7, 2, 3, 41, 3, 5, 4, 13, 2, 5, 30, 12, 12, 2, 2, 2, 2, 3, 2, 3, 2, 3, 3, 98, 5, 4, 316, 22, 15,
# ...

# %%
b=0
for i in range(len(a[0][0][1])):
    if a[0][0][1][i]>300:
        b= b+1
        plt.plot(a[1][0][i])
        plt.show()
        print(i , b)
# Out:
# 0 1
# 24 2
# 37 3
# 38 4
# 41 5
# 49 6
# 85 7
# 92 8
# 117 9
# 119 10
# 142 11
# 154 12
# 199 13
# 279 14
# 297 15
# 315 16
# 582 17
